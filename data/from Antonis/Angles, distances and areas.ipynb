# %%
import math
import pandas as pd
import numpy as np

# %% [markdown]
# Smoothing data

# %%
https://scikit-learn.org/stable/modules/impute.html
    maybe removing points that have less than 0.50 likelihood -> NaN
    and then choosing a missing values method to help smooth.

# %% [markdown]
# Distances

# %%
p = [coordinates 1 point]
q = [coordinates 1 point]
math.dist(p,q)

for all body parts in list:
    find pair distance with eachother/ or specifcy which distances I want to know
    save in dataframe with header and video also attached.

# %% [markdown]
# Angles

# %% [markdown]
# Areas

# %%
row = 2
cols = 2
Random = np.random.randint(low=0, high=5, size=(row, cols))

df = pd.DataFrame(Random)
df2 = pd.DataFrame(Random)

print(df)
print(df2)
# Out:
#    0  1
# 0  0  1
# 1  4  4
#    0  1
# 0  0  1
# 1  4  4

# %%
print(pd.concat([df,df2],ignore_index=True))
# Out:
#    0  1
# 0  0  1
# 1  4  4
# 2  0  1
# 3  4  4
