# %%
from rayleighanal import double_rayleigh

double_rayleigh("data/from Antonis/CDKL_OLR_Prob_CKL210", p0=[1, 2, 0.5], sfs=20, bins=50, minlike=0.8, percentile=99, plotting=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 3
#       1 from rayleighanal import double_rayleigh
# ----> 3 double_rayleigh("data/from Antonis/CDKL_OLR_Prob_CKL210", p0=[1, 2, 0.5], sfs=20, bins=50, minlike=0.8, percentile=99, plotting=True)
#
# File c:\Users\sebas\OneDrive\Skrivebord\KU\Data og Projekt\Data og projekt python\forsteorsprojekt\rayleighanal.py:6, in double_rayleigh(path, p0, sfs, bins, minlike, percentile, plotting)
#       4 import numpy as np
#       5 from scipy.optimize import minimize
# ----> 6 data=np.genfromtxt(path,delimiter=",",skip_header=1)
#       8 nlike=data[:,3]
#       9 ellike=data[:,6]
#
# ...
