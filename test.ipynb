# %%
bins=50
sfs=8
minlike=0.8
percentile=99
method="MCMC"
par,err=double_rayleigh("mus.csv", p0=[8, 50, 0.5], sfs=sfs, bins=bins, minlike=minlike, percentile=percentile, plotting=True,method=method)
sigma1, sigma2, weight, D1, D2 = par

if err[0] is not None:
    print(f"{sigma1=:.2f}±{err[0]:.2f}, {sigma2=:.2f}±{err[1]:.2f}, {weight=:.2f}±{err[2]:.2f}, {D1=:.2e}±{err[3]:.2e}, {D2=:.2e}±{err[4]:.2e}")
else:
    print(f"{sigma1=:.2f}, {sigma2=:.2f}, {weight=:.2f}, {D1=:.2e}, {D2=:.2e}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       4 percentile=99
#       5 method="MCMC"
# ----> 6 par,err=double_rayleigh("mus.csv", p0=[8, 50, 0.5], sfs=sfs, bins=bins, minlike=minlike, percentile=percentile, plotting=True,method=method)
#       7 sigma1, sigma2, weight, D1, D2 = par
#       9 if err[0] is not None:
#
# NameError: name 'double_rayleigh' is not defined

# %% [markdown]
# #MCMC results
#
# $sigma1=7.79±1.22, sigma2=62.64±3.32, weight=0.53±0.05, D1=7.58e+01±2.38e+01, D2=4.90e+03±5.19e+02$
#
# .
#
# $sigma1=7.66±1.19, sigma2=62.00±3.19, weight=0.52±0.05, D1=7.34e+01±2.27e+01, D2=4.80e+03±4.95e+02$
#
# .
#
#
# $sigma1=7.64±1.15, sigma2=61.80±2.98, weight=0.52±0.05, D1=7.30e+01±2.21e+01, D2=4.77e+03±4.61e+02$
#
# ,
#
#
# $10000000 iterations$
#
# ,
#
# $sigma1=7.72±1.24, sigma2=62.31±3.57, weight=0.52±0.05, D1=7.46e+01±2.39e+01, D2=4.85e+03±5.56e+02$
#
# #MLE results
# $sigma1=6.97, sigma2=60.47, weight=0.50, D1=6.08e+01, D2=4.57e+03$
